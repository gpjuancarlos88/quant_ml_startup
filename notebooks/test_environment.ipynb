# %%
import pandas as pd, numpy as np, matplotlib.pyplot as plt, yfinance as yf
print("✅ All libraries imported successfully!")

data = yf.download("SPY", start="2020-01-01", end="2020-12-31")
data["Close"].plot(title="SPY Closing Price (2020)")
plt.show()
# Out:
# ✅ All libraries imported successfully!
# C:\Users\jgarc\AppData\Local\Temp\ipykernel_13760\3950678305.py:4: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download("SPY", start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
