# %%
import os
import sys

# %%
sys.path.append(os.path.abspath(".."))

# %%
from src.data_pipeline import plot_data
plot_data("SPY", "../data")
# Out:
# c:\Dev\quant_ml_startup\src\data_pipeline.py:44: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df = pd.read_csv(file_path, index_col=0, parse_dates=True)

# %%
import pandas as pd
df = pd.read_csv("../data/features/SPY_features.csv", index_col=0, parse_dates=True)
print(df.tail())
df[["Close","SMA_10","SMA_30","RSI_14"]].plot(figsize=(10,5), title="SPY Close & Indicators")
# Out:
# C:\Users\jgarc\AppData\Local\Temp\ipykernel_22992\2425275710.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df = pd.read_csv("../data/features/SPY_features.csv", index_col=0, parse_dates=True)
#            Price       Close        High         Low        Open    Volume  \
# 1969  2025-10-29  687.390015  689.700012  682.869995  688.719971  85657100
# 1970  2025-10-30  679.830017  685.940002  679.830017  683.900024  76335800
# 1971  2025-10-31  682.059998  685.080017  679.239990  685.039978  87164100
# 1972  2025-11-03  683.340027  685.799988  679.940002  685.669983  57315000
# 1973  2025-11-04  675.239990  679.950012  674.580017  676.109985  69660714
#
#           SMA_10      SMA_30      EMA_10      EMA_30     MOM_5    VOL_20  \
# 1969  674.412000  668.148964  677.207461  667.652136  0.029335  0.008826
# ...
